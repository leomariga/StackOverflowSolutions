# %%
from matplotlib import dates as mdates
from matplotlib.colors import ListedColormap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

cmap = ListedColormap(['white','red'])

data = pd.read_csv("data.txt","  ") 

fig = plt.figure( figsize=(10,10))
ax = fig.add_subplot(111)
print(data)


data.set_index('date', inplace=True, drop=True)
data.index = pd.to_datetime(data.index)

ax.plot(data['A'])
ax.set_xlabel('')
plt.xticks(rotation = 30)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

ax.pcolorfast(ax.get_xlim(), ax.get_ylim(),
              data['B'].values[np.newaxis],
              cmap = cmap, alpha = 0.4)
plt.axhline(y = 0, color = 'black')
plt.tight_layout()
# Out:
#           date  A  B
# 0   2020-05-04  0  0
# 1   2020-05-05  5  0
# 2   2020-05-07  2  0
# 3   2020-05-09  2  0
# 4   2020-05-18 -5  0
# 5   2020-05-19 -1  0
# 6   2020-05-20  0  0
# 7   2020-05-21  1  0
# 8   2020-05-22  0  0
# 9   2020-05-23  3  0
# 10  2020-05-24  1  1
# 11  2020-05-25  0  1
# 12  2020-05-26  4  1
# 13  2020-05-27  3  1
# C:\Users\Avell\Anaconda3\envs\opencv-env\lib\site-packages\ipykernel_launcher.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-9d2a6b1ec800> in <module>
#      24 ax.pcolorfast(ax.get_xlim(), ax.get_ylim(),
#      25               data['B'],
# ---> 26               cmap = cmap, alpha = 0.4)
#      27 plt.axhline(y = 0, color = 'black')
#      28 plt.tight_layout()
#
# ~\Anaconda3\envs\opencv-env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\opencv-env\lib\site-packages\matplotlib\axes\_axes.py in pcolorfast(self, alpha, norm, cmap, vmin, vmax, *args, **kwargs)
#    6312
#    6313         C = args[-1]
# -> 6314         nr, nc = np.shape(C)[:2]
#    6315         if len(args) == 1:
#    6316             style = "image"
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
plt.close()
